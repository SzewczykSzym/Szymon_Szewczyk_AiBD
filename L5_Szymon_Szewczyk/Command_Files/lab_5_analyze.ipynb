# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ori_data = pd.read_csv("../Original_Data/drinks.csv") # original data
data_1 = pd.read_csv("../Analysis_Data/at_least_one_drink.csv") # those countries, whose citizens drink any alcohol
data_2 = pd.read_csv("../Analysis_Data/every_one_drink.csv") # those countries whose citizens drink 10 servings of every alcohol

# %%
ori_data.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
data_1.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     180.000000       180.000000     180.000000
# mean      113.827778        86.844444      53.022222
# std       100.475230        88.596431      81.379239
# min         0.000000         0.000000       0.000000
# 25%        25.000000        11.000000       2.000000
# 50%        80.500000        66.000000       9.500000
# 75%       193.250000       133.000000      73.250000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    180.000000
# mean                       5.057778
# std                        3.679552
# min                        0.100000
# 25%                        1.775000
# 50%                        4.800000
# 75%                        7.625000
# max                       14.400000

# %%
data_2.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     155.000000       155.000000     155.000000
# mean      128.045161        97.219355      58.638710
# std       100.715579        88.561320      83.873737
# min         1.000000         1.000000       1.000000
# 25%        36.000000        22.000000       4.000000
# 50%       105.000000        75.000000      13.000000
# 75%       204.500000       146.000000      82.500000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    155.000000
# mean                       5.515484
# std                        3.623788
# min                        0.100000
# 25%                        2.200000
# 50%                        5.400000
# 75%                        8.250000
# max                       14.400000

# %%
data_1
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0              Albania             89              132             54
# 1              Algeria             25                0             14
# 2              Andorra            245              138            312
# 3               Angola            217               57             45
# 4    Antigua & Barbuda            102              128             45
# ..                 ...            ...              ...            ...
# 175          Venezuela            333              100              3
# 176            Vietnam            111                2              1
# 177              Yemen              6                0              0
# 178             Zambia             32               19              4
# 179           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             4.9
# 1                             0.7
# ...

# %%
data_1.sort_values("total_litres_of_pure_alcohol").plot.bar(x="country", y="total_litres_of_pure_alcohol", figsize=(50,50))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
data_1.nlargest(15, "total_litres_of_pure_alcohol")
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 13              Belarus            142              373             42
# 92            Lithuania            343              244             56
# 2               Andorra            245              138            312
# 65              Grenada            199              438             28
# 43       Czech Republic            361              170            134
# 58               France            127              151            370
# 130  Russian Federation            247              326             73
# 77              Ireland            313              118            165
# 93           Luxembourg            236              133            271
# 143            Slovakia            196              293            116
# 62              Germany            346              117            175
# 72              Hungary            234              215            185
# ...

# %%
data_2.nsmallest(15, "beer_servings").plot.bar(x="country", y="beer_servings")
# Out:
# <AxesSubplot:xlabel='country'>

# %%
data_2.nsmallest(15, "spirit_servings").plot.bar(x="country", y="spirit_servings")
# Out:
# <AxesSubplot:xlabel='country'>

# %%
data_2.nsmallest(25, "wine_servings").plot.bar(x="country", y="wine_servings")
# Out:
# <AxesSubplot:xlabel='country'>

# %%
data_1.sum()
# Out:
# country                         AlbaniaAlgeriaAndorraAngolaAntigua & BarbudaAr...
# beer_servings                                                               20489
# spirit_servings                                                             15632
# wine_servings                                                                9544
# total_litres_of_pure_alcohol                                                910.4
# dtype: object
